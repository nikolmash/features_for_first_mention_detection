# %%
import sqlite3
import wget
from ufal.udpipe import Model, Pipeline

# %% [markdown]
# Подключаемся к уже созданное базе данных с упоминаниями и предложениями

# %%
conn = sqlite3.connect('mentions.db')
c = conn.cursor()

# %% [markdown]
# Подготавливаем к работе Udpipe, который будет производить токенизацию, лемматизацию, парсинг и разметку частей речи

# %%
udpipe_url = 'https://rusvectores.org/static/models/udpipe_syntagrus.model'
modelfile = wget.download(udpipe_url)
model = Model.load(modelfile)
process_pipeline = Pipeline(model, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, 'conllu')
# Out:
# 100% [........................................................................] 40616122 / 40616122

# %%
# создадим функцию, которая будет парсить заданные на вход строки
def parsing(text):
    # обрабатываем текст, получаем результат в формате conllu:
    processed = process_pipeline.process(text)
     # пропускаем строки со служебной информацией:
    content = [l for l in processed.split('\n') if not l.startswith('#')]
    # извлекаем из обработанного текста леммы, тэги и морфологические характеристики
    tagged = [w.split('\t') for w in content if w]
    return tagged

# %% [markdown]
# Удалим из базы данных все строчки, где именная группа является одиночным местоимением, потому что эти данные не подойдут для поставленной задачи и исследуемых признаков

# %%
c.execute('SELECT Именная_группа FROM mentions')
clmn_mentions = c.fetchall()  #  столбец базы данных, являющая списком кортежей
all_mentions = []  #  список для упоминаний
for x in clmn_mentions: 
    mention = x[0]
    all_mentions.append(mention) 
    #  преобразуем столбец в список упоминаний:
    mention_tg = parsing(mention)
    for token in mention_tg:
        if token[3] == 'PRON'and len(mention_tg)==1:  # проверка, что именная группа состоит из одного местоимения
            # удаляем такие упоминания из базы данных
            c.execute('DELETE FROM mentions WHERE Именная_группа=?', (mention,))
            conn.commit()

# %% [markdown]
# 1. Длина именной группы

# %%
import numpy as np 


np_length = []  #  будущий список для длин каждой именной группы в словах
for mention in all_mentions:
    np_length.append(len(mention.split()))  #  добавляем длину каждой именной группы в список
mean_length = np.mean(np.array(np_length))  #  рассчитываем среднюю длину
# сравниваем длину каждой именной группы со средним показателем и на основе этого формируем бинарный признака
feature_1 = []
for num in np_length:
    if num>mean_length:
        feature_1.append(1)
    else:
        feature_1.append(0)

# %% [markdown]
# 2. Позиция ремы

# %%
c.execute('SELECT Предложение FROM mentions')
clmn_sentences = c.fetchall() # столбец предложений из базы данных
all_sentences = [] # будущий список для предложений
feature_2 = [] # будущий вектор признака
# преобразуем список кортежей в список строк
for x in clmn_sentences:
    sentence = x[0]
    all_sentences.append(sentence) 
for i in range(len(all_sentences)):
    center = len(all_sentences[i])//2  # находим середину предложения
    mention_start = all_sentences[i].find(all_mentions[i])  # индекс первого символа упоминания в данном предложении
    mention_finish = mention_start + len(all_mentions[i])  # индекс последнего символа упоминания в данном предложении
    # в зависимости от трех возможных расположений именной группы относительно центра формируем признаковый вектор
    if mention_start<center and mention_finish<center:
        x = 0
    elif mention_start<center and mention_finish>center:
        x = 1
    elif mention_start>center and mention_finish>center:
        x = 2
    feature_2.append(x)

# %% [markdown]
# 3. Позиция в тексте

# %%
feature_3 = []
c.execute('SELECT Файл FROM mentions') 
clmn_files = c.fetchall() # столбец из базы данных с номерами файлов, из которых взяты предложения
# для каждого предложения и текста, из которого оно взято, смотрим на позицию
for i in range(len(all_sentences)):
    text_num = clmn_files[i][0]
    pathtext = './ForTraining/Texts/book_%d.txt' % text_num
    with open(pathtext, encoding='utf-8') as g:  # открывается сам текст
        text = g.read()
    sentences = text.splitlines()  #  текст делится на предожения
    text_to_3 = len(sentences)//3*3  # делим предложения текста на 3 части
    third1 = sentences[0:text_to_3//3]
    third2 = sentences[text_to_3//3:2*text_to_3//3]
    third3 = sentences[2*text_to_3:]
    # проверка вхождения данного предложения в первую, вторую и третью треть текста
    if all_sentences[i] in third1:
        x = 2
    elif all_sentences[i] in third2:
        x = 1
    elif all_sentences[i] in third3:
        x = 0
    feature_3.append(x)

# %% [markdown]
#  4. Позиция подлежащего

# %%
feature_4 = [] # будущий вектор признака
for i in range(len(all_mentions)):
    x = 0
    mention_prs = parsing(all_mentions[i]) # обрабатываем udpipe каждую именную группу
    sentence_prs = parsing(all_sentences[i]) # обрабатываем udpipe каждое предложение
    # находим в именной группе вершину:
    for token in mention_prs: 
        if token[7] == 'root':
            mention_root = token[1]
    words = all_sentences[i].split() # предложение, поделенное на слова
    for j in range(len(words)):
        if words[j] == mention_root:
            mention_pos = j  # найдена позиция вершины именной группы в предложении
            if sentence_prs[mention_pos][7]=='nsubj': # проверка, что именно вершина ИГ является подлежащим
                x = 1
    feature_4.append(x)

# %% [markdown]
# 5. Количество прилагательных в именной группе

# %%
adnum_length = []  #  будущий список для кол-ва прилагательных в каждой ИГ
for mention in all_mentions:
    adnum = 0
    mention_prs = parsing(mention)
    for token in mention_prs: # среди разбитого на токены упоминания ищем прилагательные
        if token[3] == 'ADJ':
            adnum += 1
    adnum_length.append(adnum) #  добавляем кол-во прилагательных в данной ИГ в список
mean_num = np.mean(np.array(adnum_length))  #  рассчитываем среднее количество
# сравниваем кол-во прилагательных каждой ИГ со средним показателем и на основе этого формируем бинарный признака
feature_5 = []
for num in adnum_length:
    if num>mean_num:
        feature_5.append(1)
    else:
        feature_5.append(0)

# %% [markdown]
# 6. Имена собственные в именной группе

# %%
import re

feature_6 = []
for mention in all_mentions:
    mention_prs = parsing(mention)
    prop_names = 0 # кол-во имен собственных в ИГ
    brackets = 0  # кол-во названий с кавычками в ИГ
    foreign = 0 # кол-во иностранных слов в ИГ
    abbr = 0  # кол-во аббревиатур в ИГ
    for toren in mention_prs:
        if token[3] == 'PROPN':  # проверка на имя собственное
            prop_names += 1
        if token[7] == 'flat:foreign': # проверка на иностранное слово
            foreign += 1
    match_brackets = re.search(r'"[А-Яа-я ]+"', mention) # поиск названий в кавычках
    if match_brackets:
        brackets += 1
    match_abbr = re.search('[А-Я]+', mention) # поиск аббревиатур
    if match_abbr:
        abbr += 1
    x = 0
    # проверка выполнения хотя бы одного из условий, чтобы можно было назвать первым упоминанием
    if len(mention_prs)>1 and prop_names>1 or brackets>0 or foreign>0 or abbr>0 and len(mention_prs)>1:
        x = 1
    feature_6.append(x)

# %% [markdown]
# 7. Рестриктивные постмодификации

# %%
feature_7 = []
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)  
    for token in mention_prs:
        if 'acl' in token[7]: # поиск соответствующего тега среди размеченной ИГ
            x = 1
    feature_7.append(x)

# %% [markdown]
# 8. Приложения

# %%
feature_8 = []
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    for token in mention_prs:
        if token[7] == 'appos': # поиск соответствующего тега среди размеченной ИГ
            x = 1
    feature_8.append(x)

# %% [markdown]
# 9. Квазибытийные глаголы

# %%
feature_9 = []
with open('списки слов\глаголы.txt', encoding='utf-8') as f:
    verbs = f.readlines()
# по категориям запишем файл в списки:
exist1 = verbs[0].split() 
exist2 = verbs[1].split()
speech = verbs[2].split()
for i in range(len(all_mentions)):
    sentence_prs = parsing(all_sentences[i])
    mention_prs = parsing(all_mentions[i])
    x1,x2 = 0, 0 # показатели, которые понадобятся при выводе итогового значения признака
    # нахождение вершины ИГ:
    for token in mention_prs:
        if token[7] == 'root':
            mention_root = token[1]
    # для каждого предложения проверим выполнение условий
    for j in range(len(sentence_prs)):
        # если подлежащее - вершина ИГ, а сказуемое - глагол из exist1
        if sentence_prs[j][1] == mention_root and sentence_prs[j][7]=='nsubj':
            x1 = 1
        if sentence_prs[j][2] in exist1 and sentence_prs[j][7]=='root':
                x2 = 1
        # если вершина ИГ - прямое дополнение глагола из exist2
        if sentence_prs[j][1] == mention_root and sentence_prs[j][7]=='obj':
            x1 = 1
        if sentence_prs[j][2] in exist2 and sentence_prs[j][7]=='root':
            x2 = 1
        # если вершина ИГ является зависимым предикатов речи из speech
        if sentence_prs[j][1] == mention_root and sentence_prs[j][7]=='obl':
            x1 = 1
        if sentence_prs[j][2] in speech and sentence_prs[j][7]=='root':
            x2 = 1
    # необходимо одновременное выполнение x1 и x2, поэтому используем произведение
    feature_9.append(x1*x2)

# %% [markdown]
# 10. Модификаторы

# %%
feature_10 = []
with open('списки слов\прилагательные.txt', encoding='utf-8') as f:
    modifiers = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов или на превосходную степень прилагательного
    for token in mention_prs:
        if token[2] in modifiers or 'Degree=Sup' in token[5]:
            x = 1
    feature_10.append(x)

# %% [markdown]
# 11. Неопределенные маркеры

# %%
feature_11 = []
with open('списки слов\неопределенные маркеры.txt', encoding='utf-8') as f:
    markers = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов
    for token in mention_prs:
        if token[2] in modifiers:
            x = 1
    feature_11.append(x)

# %% [markdown]
# 12. Маркеры неравноправия

# %%
feature_12 = []
with open('списки слов\маркеры неравноправия.txt', encoding='utf-8') as f:
    markers = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов
    for token in mention_prs:
        if token[2] in modifiers:
            x = 1
    feature_12.append(x)

# %% [markdown]
# 13. Маркеры схожести

# %%
feature_13 = []
with open('списки слов\маркеры схожести.txt', encoding='utf-8') as f:
    markers = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов
    for token in mention_prs:
        if token[2] in modifiers:
            x = 1
    feature_13.append(x)

# %% [markdown]
# 14. Предикаты, комплементом которых служат новые упоминания

# %%
feature_14 = []
with open('списки слов\предикаты.txt', encoding='utf-8') as f:
    predicates = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов
    for token in mention_prs:
        if token[2] in predicates:
            x = 1
    feature_14.append(x)

# %% [markdown]
# 15. Объекты, существование которых точно известно

# %%
feature_15 = []
with open('списки слов\объекты.txt', encoding='utf-8') as f:
    objects = f.read().split()
for mention in all_mentions:
    x = 0
    mention_prs = parsing(mention)
    # проверка каждого токена ИГ на вхождение в составленный список слов
    for token in mention_prs:
        if token[2] in objects:
            x = 1
    feature_15.append(x)

# %% [markdown]
# Создадим Dataframe со всеми полученными признаками, на котором будем обучать и тестировать

# %%
import pandas as pd

df = pd.DataFrame({
    'Длина ИГ': feature_1,
    'Позиция ремы': feature_2,
    'Позиция в тексте': feature_3,
    'Подлежащее': feature_4,
    'Кол-во прил': feature_5,
    'Имена соб-е': feature_6,
    'Рестрикт': feature_7,
    'Приложения': feature_8,
    'Каузация существ.': feature_9,
    'Модификаторы': feature_10,
    'Неопр маркеры': feature_11,
    'Маркеры неравн': feature_12,
    'Маркеры схож': feature_13,
    'Предикаты': feature_14,
    'Объекты': feature_15
}, index = all_mentions)

# %% [markdown]
# Вот так выглядят все рассматриваемые именные группы, размеченные по 15 признакам:

# %%
df
# Out:
#                                                     Длина ИГ  Позиция ремы  \
# ﻿«Школа злословия»                                         0             0
#  «Школа злословия»                                         0             0
#  сценаристка Дуня Смирнова                                 1             0
#  канале «Культура»                                         0             0
#  ведущих                                                   0             0
#  «Культуры»                                                0             0
#  ведущих                                                   0             0
#  Татьяне Никитичне                                         0             0
#  Татьяны Толстой                                           0             2
#  египтологом Виктором Солкиным                             1             0
#  гость                                                     0             2
#  египтолога                                                0             0
#  Авдотья                                                   0             0
#  Шеридана                                                  0             0
#  Татьяны Лазаревой                                         0             1
#  гость                                                     0             2
#  выражение «Школа злословия»                               1             0
# ﻿«Последнее восстание»                                     0             0
#  российской арт-группы АЕС+Ф                               1             0
#  зрителю                                                   0             0
#  арт-группы АЕС+Ф                                          0             0
#  выставке                                                  0             0
#  Павичем                                                   0             2
#  Милорад Павич                                             0             2
#  его «Хазарский словарь»                                   1             0
#  интернете                                                 0             0
#  книга, которую читатель может изучать как поже...         1             0
#  тексты, которые не так-то легко разложить на г...         1             0
#  Кортасар                                                  0             0
#  Хулио Кортасар                                            0             0
# ...                                                      ...           ...
# ﻿Си Цзиньпин                                               0             0
#  Россию                                                    0             0
# «Китайский                                                 0             0
#  Второй мировой войны                                      1             0
#  президента России Владимира Путина                        1             0
#  кинофестиваль в Выборге                                   1             1
#  Станислав Говорухин                                       0             0
#  свои                                                      0             0
#  приз "Золотая ладья"                                      1             0
#  Гильдии киноведов и кинокритиков России                   1             1
#  новый фильм Станислава Говорухина "Weekend"               1             0
#  классический нуар-фильм Луи Маля 1957 года                1             0
# ﻿BP                                                        0             0
#  совет директоров британской нефтегазовой компа...         1             0
#  президент российской государственной нефтяной ...         1             2
#  ТНК-BP                                                    0             0
#  совета директоров                                         0             0
#  сделки                                                    0             2
#  переговорах                                               0             0
#  сделка                                                    0             2
# ﻿Microsoft                                                 0             0
#  интернет-гиганта Yahoo!                                   0             2
#  Билла Гейтса                                              0             0
#  один игрок                                                0             0
#  акций интернет-гиганта Yahoo!                             1             0
#  США                                                       0             0
# :Суп с репой и авокадо                                     1             1
#  воды                                                      0             2
#  авокадо                                                   0             0
#  кастрюлю                                                  0             0
#
#                                                     Позиция в тексте  \
# ﻿«Школа злословия»                                                 2
#  «Школа злословия»                                                 2
#  сценаристка Дуня Смирнова                                         2
#  канале «Культура»                                                 2
#  ведущих                                                           2
#  «Культуры»                                                        2
#  ведущих                                                           1
#  Татьяне Никитичне                                                 1
#  Татьяны Толстой                                                   1
#  египтологом Виктором Солкиным                                     1
#  гость                                                             1
#  египтолога                                                        1
#  Авдотья                                                           1
#  Шеридана                                                          1
#  Татьяны Лазаревой                                                 1
#  гость                                                             1
#  выражение «Школа злословия»                                       1
# ﻿«Последнее восстание»                                             2
#  российской арт-группы АЕС+Ф                                       2
#  зрителю                                                           2
#  арт-группы АЕС+Ф                                                  2
#  выставке                                                          2
#  Павичем                                                           2
#  Милорад Павич                                                     2
#  его «Хазарский словарь»                                           2
#  интернете                                                         2
#  книга, которую читатель может изучать как поже...                 2
#  тексты, которые не так-то легко разложить на г...                 1
#  Кортасар                                                          1
#  Хулио Кортасар                                                    1
# ...                                                              ...
# ﻿Си Цзиньпин                                                       2
#  Россию                                                            2
# «Китайский                                                         1
#  Второй мировой войны                                              1
#  президента России Владимира Путина                                1
#  кинофестиваль в Выборге                                           2
#  Станислав Говорухин                                               2
#  свои                                                              1
#  приз "Золотая ладья"                                              1
#  Гильдии киноведов и кинокритиков России                           1
#  новый фильм Станислава Говорухина "Weekend"                       1
#  классический нуар-фильм Луи Маля 1957 года                        1
# ﻿BP                                                                2
#  совет директоров британской нефтегазовой компа...                 2
#  президент российской государственной нефтяной ...                 2
#  ТНК-BP                                                            1
#  совета директоров                                                 1
#  сделки                                                            1
#  переговорах                                                       1
#  сделка                                                            1
# ﻿Microsoft                                                         2
#  интернет-гиганта Yahoo!                                           2
#  Билла Гейтса                                                      1
#  один игрок                                                        1
#  акций интернет-гиганта Yahoo!                                     1
#  США                                                               1
# :Суп с репой и авокадо                                             2
#  воды                                                              1
#  авокадо                                                           1
#  кастрюлю                                                          1
#
#                                                     Подлежащее  Кол-во прил  \
# ﻿«Школа злословия»                                           1            0
#  «Школа злословия»                                           1            0
#  сценаристка Дуня Смирнова                                   0            0
#  канале «Культура»                                           0            0
#  ведущих                                                     0            1
#  «Культуры»                                                  0            0
#  ведущих                                                     0            1
#  Татьяне Никитичне                                           0            0
#  Татьяны Толстой                                             0            1
#  египтологом Виктором Солкиным                               0            0
#  гость                                                       0            0
#  египтолога                                                  0            0
#  Авдотья                                                     0            0
#  Шеридана                                                    0            0
#  Татьяны Лазаревой                                           0            1
#  гость                                                       0            0
#  выражение «Школа злословия»                                 0            0
# ﻿«Последнее восстание»                                       0            0
#  российской арт-группы АЕС+Ф                                 0            1
#  зрителю                                                     0            0
#  арт-группы АЕС+Ф                                            0            0
#  выставке                                                    0            0
#  Павичем                                                     0            0
#  Милорад Павич                                               1            0
#  его «Хазарский словарь»                                     0            1
#  интернете                                                   0            0
#  книга, которую читатель может изучать как поже...           0            0
#  тексты, которые не так-то легко разложить на г...           0            1
#  Кортасар                                                    0            0
#  Хулио Кортасар                                              0            0
# ...                                                        ...          ...
# ﻿Си Цзиньпин                                                 1            0
#  Россию                                                      0            0
# «Китайский                                                   0            1
#  Второй мировой войны                                        0            1
#  президента России Владимира Путина                          0            0
#  кинофестиваль в Выборге                                     1            0
#  Станислав Говорухин                                         0            0
#  свои                                                        0            0
#  приз "Золотая ладья"                                        0            1
#  Гильдии киноведов и кинокритиков России                     0            0
#  новый фильм Станислава Говорухина "Weekend"                 1            1
#  классический нуар-фильм Луи Маля 1957 года                  0            1
# ﻿BP                                                          1            0
#  совет директоров британской нефтегазовой компа...           1            1
#  президент российской государственной нефтяной ...           0            1
#  ТНК-BP                                                      0            0
#  совета директоров                                           0            0
#  сделки                                                      0            0
#  переговорах                                                 0            0
#  сделка                                                      0            0
# ﻿Microsoft                                                   1            0
#  интернет-гиганта Yahoo!                                     0            0
#  Билла Гейтса                                                0            0
#  один игрок                                                  0            0
#  акций интернет-гиганта Yahoo!                               0            0
#  США                                                         0            0
# :Суп с репой и авокадо                                       0            0
#  воды                                                        0            0
#  авокадо                                                     0            0
#  кастрюлю                                                    1            0
#
#                                                     Имена соб-е  Рестрикт  \
# ﻿«Школа злословия»                                            1         0
#  «Школа злословия»                                            1         0
#  сценаристка Дуня Смирнова                                    1         0
#  канале «Культура»                                            1         0
#  ведущих                                                      0         0
#  «Культуры»                                                   0         0
#  ведущих                                                      0         0
#  Татьяне Никитичне                                            1         0
#  Татьяны Толстой                                              1         0
#  египтологом Виктором Солкиным                                1         0
#  гость                                                        0         0
#  египтолога                                                   0         0
#  Авдотья                                                      0         0
#  Шеридана                                                     0         0
#  Татьяны Лазаревой                                            1         0
#  гость                                                        0         0
#  выражение «Школа злословия»                                  1         0
# ﻿«Последнее восстание»                                        1         0
#  российской арт-группы АЕС+Ф                                  1         0
#  зрителю                                                      0         0
#  арт-группы АЕС+Ф                                             1         0
#  выставке                                                     0         0
#  Павичем                                                      0         0
#  Милорад Павич                                                1         0
#  его «Хазарский словарь»                                      1         0
#  интернете                                                    0         0
#  книга, которую читатель может изучать как поже...            0         1
#  тексты, которые не так-то легко разложить на г...            0         1
#  Кортасар                                                     0         0
#  Хулио Кортасар                                               1         0
# ...                                                         ...       ...
# ﻿Си Цзиньпин                                                  1         0
#  Россию                                                       0         0
# «Китайский                                                    0         0
#  Второй мировой войны                                         1         0
#  президента России Владимира Путина                           1         0
#  кинофестиваль в Выборге                                      1         0
#  Станислав Говорухин                                          1         0
#  свои                                                         0         0
#  приз "Золотая ладья"                                         1         0
#  Гильдии киноведов и кинокритиков России                      1         0
#  новый фильм Станислава Говорухина "Weekend"                  1         0
#  классический нуар-фильм Луи Маля 1957 года                   1         0
# ﻿BP                                                           0         0
#  совет директоров британской нефтегазовой компа...            0         0
#  президент российской государственной нефтяной ...            1         0
#  ТНК-BP                                                       0         0
#  совета директоров                                            0         0
#  сделки                                                       0         0
#  переговорах                                                  0         0
#  сделка                                                       0         0
# ﻿Microsoft                                                    0         0
#  интернет-гиганта Yahoo!                                      0         0
#  Билла Гейтса                                                 1         0
#  один игрок                                                   0         0
#  акций интернет-гиганта Yahoo!                                0         0
#  США                                                          0         0
# :Суп с репой и авокадо                                        1         0
#  воды                                                         0         0
#  авокадо                                                      0         0
#  кастрюлю                                                     0         0
#
#                                                     Приложения  \
# ﻿«Школа злословия»                                           0
#  «Школа злословия»                                           0
#  сценаристка Дуня Смирнова                                   1
#  канале «Культура»                                           0
#  ведущих                                                     0
#  «Культуры»                                                  0
#  ведущих                                                     0
#  Татьяне Никитичне                                           0
#  Татьяны Толстой                                             0
#  египтологом Виктором Солкиным                               1
#  гость                                                       0
#  египтолога                                                  0
#  Авдотья                                                     0
#  Шеридана                                                    0
#  Татьяны Лазаревой                                           0
#  гость                                                       0
#  выражение «Школа злословия»                                 0
# ﻿«Последнее восстание»                                       0
#  российской арт-группы АЕС+Ф                                 0
#  зрителю                                                     0
#  арт-группы АЕС+Ф                                            0
#  выставке                                                    0
#  Павичем                                                     0
#  Милорад Павич                                               1
#  его «Хазарский словарь»                                     0
#  интернете                                                   0
#  книга, которую читатель может изучать как поже...           0
#  тексты, которые не так-то легко разложить на г...           0
#  Кортасар                                                    0
#  Хулио Кортасар                                              1
# ...                                                        ...
# ﻿Си Цзиньпин                                                 0
#  Россию                                                      0
# «Китайский                                                   0
#  Второй мировой войны                                        0
#  президента России Владимира Путина                          1
#  кинофестиваль в Выборге                                     0
#  Станислав Говорухин                                         1
#  свои                                                        0
#  приз "Золотая ладья"                                        0
#  Гильдии киноведов и кинокритиков России                     0
#  новый фильм Станислава Говорухина "Weekend"                 1
#  классический нуар-фильм Луи Маля 1957 года                  1
# ﻿BP                                                          0
#  совет директоров британской нефтегазовой компа...           0
#  президент российской государственной нефтяной ...           1
#  ТНК-BP                                                      0
#  совета директоров                                           0
#  сделки                                                      0
#  переговорах                                                 0
#  сделка                                                      0
# ﻿Microsoft                                                   0
#  интернет-гиганта Yahoo!                                     1
#  Билла Гейтса                                                0
#  один игрок                                                  0
#  акций интернет-гиганта Yahoo!                               0
#  США                                                         0
# :Суп с репой и авокадо                                       0
#  воды                                                        0
#  авокадо                                                     0
#  кастрюлю                                                    0
#
#                                                     Каузация существ.  \
# ﻿«Школа злословия»                                                  0
#  «Школа злословия»                                                  0
#  сценаристка Дуня Смирнова                                          0
#  канале «Культура»                                                  0
#  ведущих                                                            0
#  «Культуры»                                                         0
#  ведущих                                                            0
#  Татьяне Никитичне                                                  0
#  Татьяны Толстой                                                    0
#  египтологом Виктором Солкиным                                      1
#  гость                                                              0
#  египтолога                                                         0
#  Авдотья                                                            0
#  Шеридана                                                           0
#  Татьяны Лазаревой                                                  0
#  гость                                                              0
#  выражение «Школа злословия»                                        0
# ﻿«Последнее восстание»                                              0
#  российской арт-группы АЕС+Ф                                        0
#  зрителю                                                            0
#  арт-группы АЕС+Ф                                                   0
#  выставке                                                           1
#  Павичем                                                            0
#  Милорад Павич                                                      1
#  его «Хазарский словарь»                                            0
#  интернете                                                          0
#  книга, которую читатель может изучать как поже...                  0
#  тексты, которые не так-то легко разложить на г...                  1
#  Кортасар                                                           0
#  Хулио Кортасар                                                     0
# ...                                                               ...
# ﻿Си Цзиньпин                                                        1
#  Россию                                                             0
# «Китайский                                                          0
#  Второй мировой войны                                               0
#  президента России Владимира Путина                                 0
#  кинофестиваль в Выборге                                            0
#  Станислав Говорухин                                                0
#  свои                                                               0
#  приз "Золотая ладья"                                               0
#  Гильдии киноведов и кинокритиков России                            0
#  новый фильм Станислава Говорухина "Weekend"                        1
#  классический нуар-фильм Луи Маля 1957 года                         1
# ﻿BP                                                                 0
#  совет директоров британской нефтегазовой компа...                  0
#  президент российской государственной нефтяной ...                  0
#  ТНК-BP                                                             0
#  совета директоров                                                  0
#  сделки                                                             1
#  переговорах                                                        0
#  сделка                                                             0
# ﻿Microsoft                                                          0
#  интернет-гиганта Yahoo!                                            0
#  Билла Гейтса                                                       0
#  один игрок                                                         0
#  акций интернет-гиганта Yahoo!                                      0
#  США                                                                0
# :Суп с репой и авокадо                                              0
#  воды                                                               0
#  авокадо                                                            0
#  кастрюлю                                                           0
#
#                                                     Модификаторы  \
# ﻿«Школа злословия»                                             0
#  «Школа злословия»                                             0
#  сценаристка Дуня Смирнова                                     0
#  канале «Культура»                                             0
#  ведущих                                                       0
#  «Культуры»                                                    0
#  ведущих                                                       0
#  Татьяне Никитичне                                             0
#  Татьяны Толстой                                               0
#  египтологом Виктором Солкиным                                 0
#  гость                                                         0
#  египтолога                                                    0
#  Авдотья                                                       0
#  Шеридана                                                      0
#  Татьяны Лазаревой                                             0
#  гость                                                         0
#  выражение «Школа злословия»                                   0
# ﻿«Последнее восстание»                                         0
#  российской арт-группы АЕС+Ф                                   0
#  зрителю                                                       0
#  арт-группы АЕС+Ф                                              0
#  выставке                                                      0
#  Павичем                                                       0
#  Милорад Павич                                                 0
#  его «Хазарский словарь»                                       0
#  интернете                                                     0
#  книга, которую читатель может изучать как поже...             0
#  тексты, которые не так-то легко разложить на г...             0
#  Кортасар                                                      0
#  Хулио Кортасар                                                0
# ...                                                          ...
# ﻿Си Цзиньпин                                                   0
#  Россию                                                        0
# «Китайский                                                     0
#  Второй мировой войны                                          1
#  президента России Владимира Путина                            0
#  кинофестиваль в Выборге                                       0
#  Станислав Говорухин                                           0
#  свои                                                          0
#  приз "Золотая ладья"                                          0
#  Гильдии киноведов и кинокритиков России                       0
#  новый фильм Станислава Говорухина "Weekend"                   1
#  классический нуар-фильм Луи Маля 1957 года                    0
# ﻿BP                                                            0
#  совет директоров британской нефтегазовой компа...             0
#  президент российской государственной нефтяной ...             0
#  ТНК-BP                                                        0
#  совета директоров                                             0
#  сделки                                                        0
#  переговорах                                                   0
#  сделка                                                        0
# ﻿Microsoft                                                     0
#  интернет-гиганта Yahoo!                                       0
#  Билла Гейтса                                                  0
#  один игрок                                                    0
#  акций интернет-гиганта Yahoo!                                 0
#  США                                                           0
# :Суп с репой и авокадо                                         0
#  воды                                                          0
#  авокадо                                                       0
#  кастрюлю                                                      0
#
#                                                     Неопр маркеры  \
# ﻿«Школа злословия»                                              0
#  «Школа злословия»                                              0
#  сценаристка Дуня Смирнова                                      0
#  канале «Культура»                                              0
#  ведущих                                                        0
#  «Культуры»                                                     0
#  ведущих                                                        0
#  Татьяне Никитичне                                              0
#  Татьяны Толстой                                                0
#  египтологом Виктором Солкиным                                  0
#  гость                                                          0
#  египтолога                                                     0
#  Авдотья                                                        0
#  Шеридана                                                       0
#  Татьяны Лазаревой                                              0
#  гость                                                          0
#  выражение «Школа злословия»                                    0
# ﻿«Последнее восстание»                                          0
#  российской арт-группы АЕС+Ф                                    0
#  зрителю                                                        0
#  арт-группы АЕС+Ф                                               0
#  выставке                                                       0
#  Павичем                                                        0
#  Милорад Павич                                                  0
#  его «Хазарский словарь»                                        0
#  интернете                                                      0
#  книга, которую читатель может изучать как поже...              0
#  тексты, которые не так-то легко разложить на г...              0
#  Кортасар                                                       0
#  Хулио Кортасар                                                 0
# ...                                                           ...
# ﻿Си Цзиньпин                                                    0
#  Россию                                                         0
# «Китайский                                                      0
#  Второй мировой войны                                           1
#  президента России Владимира Путина                             0
#  кинофестиваль в Выборге                                        0
#  Станислав Говорухин                                            0
#  свои                                                           0
#  приз "Золотая ладья"                                           0
#  Гильдии киноведов и кинокритиков России                        0
#  новый фильм Станислава Говорухина "Weekend"                    1
#  классический нуар-фильм Луи Маля 1957 года                     0
# ﻿BP                                                             0
#  совет директоров британской нефтегазовой компа...              0
#  президент российской государственной нефтяной ...              0
#  ТНК-BP                                                         0
#  совета директоров                                              0
#  сделки                                                         0
#  переговорах                                                    0
#  сделка                                                         0
# ﻿Microsoft                                                      0
#  интернет-гиганта Yahoo!                                        0
#  Билла Гейтса                                                   0
#  один игрок                                                     0
#  акций интернет-гиганта Yahoo!                                  0
#  США                                                            0
# :Суп с репой и авокадо                                          0
#  воды                                                           0
#  авокадо                                                        0
#  кастрюлю                                                       0
#
#                                                     Маркеры неравн  \
# ﻿«Школа злословия»                                               0
#  «Школа злословия»                                               0
#  сценаристка Дуня Смирнова                                       0
#  канале «Культура»                                               0
#  ведущих                                                         0
#  «Культуры»                                                      0
#  ведущих                                                         0
#  Татьяне Никитичне                                               0
#  Татьяны Толстой                                                 0
#  египтологом Виктором Солкиным                                   0
#  гость                                                           0
#  египтолога                                                      0
#  Авдотья                                                         0
#  Шеридана                                                        0
#  Татьяны Лазаревой                                               0
#  гость                                                           0
#  выражение «Школа злословия»                                     0
# ﻿«Последнее восстание»                                           0
#  российской арт-группы АЕС+Ф                                     0
#  зрителю                                                         0
#  арт-группы АЕС+Ф                                                0
#  выставке                                                        0
#  Павичем                                                         0
#  Милорад Павич                                                   0
#  его «Хазарский словарь»                                         0
#  интернете                                                       0
#  книга, которую читатель может изучать как поже...               0
#  тексты, которые не так-то легко разложить на г...               0
#  Кортасар                                                        0
#  Хулио Кортасар                                                  0
# ...                                                            ...
# ﻿Си Цзиньпин                                                     0
#  Россию                                                          0
# «Китайский                                                       0
#  Второй мировой войны                                            1
#  президента России Владимира Путина                              0
#  кинофестиваль в Выборге                                         0
#  Станислав Говорухин                                             0
#  свои                                                            0
#  приз "Золотая ладья"                                            0
#  Гильдии киноведов и кинокритиков России                         0
#  новый фильм Станислава Говорухина "Weekend"                     1
#  классический нуар-фильм Луи Маля 1957 года                      0
# ﻿BP                                                              0
#  совет директоров британской нефтегазовой компа...               0
#  президент российской государственной нефтяной ...               0
#  ТНК-BP                                                          0
#  совета директоров                                               0
#  сделки                                                          0
#  переговорах                                                     0
#  сделка                                                          0
# ﻿Microsoft                                                       0
#  интернет-гиганта Yahoo!                                         0
#  Билла Гейтса                                                    0
#  один игрок                                                      0
#  акций интернет-гиганта Yahoo!                                   0
#  США                                                             0
# :Суп с репой и авокадо                                           0
#  воды                                                            0
#  авокадо                                                         0
#  кастрюлю                                                        0
#
#                                                     Маркеры схож  Предикаты  \
# ﻿«Школа злословия»                                             0          0
#  «Школа злословия»                                             0          0
#  сценаристка Дуня Смирнова                                     0          0
#  канале «Культура»                                             0          0
#  ведущих                                                       0          0
#  «Культуры»                                                    0          0
#  ведущих                                                       0          0
#  Татьяне Никитичне                                             0          0
#  Татьяны Толстой                                               0          0
#  египтологом Виктором Солкиным                                 0          0
#  гость                                                         0          0
#  египтолога                                                    0          0
#  Авдотья                                                       0          0
#  Шеридана                                                      0          0
#  Татьяны Лазаревой                                             0          0
#  гость                                                         0          0
#  выражение «Школа злословия»                                   0          0
# ﻿«Последнее восстание»                                         0          0
#  российской арт-группы АЕС+Ф                                   0          0
#  зрителю                                                       0          0
#  арт-группы АЕС+Ф                                              0          0
#  выставке                                                      0          0
#  Павичем                                                       0          0
#  Милорад Павич                                                 0          0
#  его «Хазарский словарь»                                       0          0
#  интернете                                                     0          0
#  книга, которую читатель может изучать как поже...             0          0
#  тексты, которые не так-то легко разложить на г...             0          0
#  Кортасар                                                      0          0
#  Хулио Кортасар                                                0          0
# ...                                                          ...        ...
# ﻿Си Цзиньпин                                                   0          0
#  Россию                                                        0          0
# «Китайский                                                     0          0
#  Второй мировой войны                                          1          0
#  президента России Владимира Путина                            0          0
#  кинофестиваль в Выборге                                       0          0
#  Станислав Говорухин                                           0          0
#  свои                                                          0          0
#  приз "Золотая ладья"                                          0          0
#  Гильдии киноведов и кинокритиков России                       0          0
#  новый фильм Станислава Говорухина "Weekend"                   1          0
#  классический нуар-фильм Луи Маля 1957 года                    0          0
# ﻿BP                                                            0          0
#  совет директоров британской нефтегазовой компа...             0          0
#  президент российской государственной нефтяной ...             0          0
#  ТНК-BP                                                        0          0
#  совета директоров                                             0          0
#  сделки                                                        0          0
#  переговорах                                                   0          0
#  сделка                                                        0          0
# ﻿Microsoft                                                     0          0
#  интернет-гиганта Yahoo!                                       0          0
#  Билла Гейтса                                                  0          0
#  один игрок                                                    0          0
#  акций интернет-гиганта Yahoo!                                 0          0
#  США                                                           0          0
# :Суп с репой и авокадо                                         0          0
#  воды                                                          0          0
#  авокадо                                                       0          0
#  кастрюлю                                                      0          0
#
#                                                     Объекты
# ﻿«Школа злословия»                                        0
#  «Школа злословия»                                        0
#  сценаристка Дуня Смирнова                                0
#  канале «Культура»                                        0
#  ведущих                                                  0
#  «Культуры»                                               0
#  ведущих                                                  0
#  Татьяне Никитичне                                        0
#  Татьяны Толстой                                          0
#  египтологом Виктором Солкиным                            0
#  гость                                                    0
#  египтолога                                               0
#  Авдотья                                                  0
#  Шеридана                                                 0
#  Татьяны Лазаревой                                        0
#  гость                                                    0
#  выражение «Школа злословия»                              0
# ﻿«Последнее восстание»                                    0
#  российской арт-группы АЕС+Ф                              0
#  зрителю                                                  0
#  арт-группы АЕС+Ф                                         0
#  выставке                                                 0
#  Павичем                                                  0
#  Милорад Павич                                            0
#  его «Хазарский словарь»                                  0
#  интернете                                                0
#  книга, которую читатель может изучать как поже...        0
#  тексты, которые не так-то легко разложить на г...        0
#  Кортасар                                                 0
#  Хулио Кортасар                                           0
# ...                                                     ...
# ﻿Си Цзиньпин                                              0
#  Россию                                                   0
# «Китайский                                                0
#  Второй мировой войны                                     0
#  президента России Владимира Путина                       0
#  кинофестиваль в Выборге                                  0
#  Станислав Говорухин                                      0
#  свои                                                     0
#  приз "Золотая ладья"                                     0
#  Гильдии киноведов и кинокритиков России                  0
#  новый фильм Станислава Говорухина "Weekend"              0
#  классический нуар-фильм Луи Маля 1957 года               1
# ﻿BP                                                       0
#  совет директоров британской нефтегазовой компа...        0
#  президент российской государственной нефтяной ...        0
#  ТНК-BP                                                   0
#  совета директоров                                        0
#  сделки                                                   0
#  переговорах                                              0
#  сделка                                                   0
# ﻿Microsoft                                                0
#  интернет-гиганта Yahoo!                                  0
#  Билла Гейтса                                             0
#  один игрок                                               0
#  акций интернет-гиганта Yahoo!                            0
#  США                                                      0
# :Суп с репой и авокадо                                    0
#  воды                                                     0
#  авокадо                                                  0
#  кастрюлю                                                 0
#
# [2289 rows x 15 columns]

# %%
df.to_csv('FFFM.csv')  # сохраняем в файл таблицу

# %%
conn.close()  # отключаемся от базы данных
